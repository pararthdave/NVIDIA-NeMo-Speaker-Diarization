# %% [markdown]
# <a href="https://colab.research.google.com/github/pararthdave/NVIDIA-NeMo-Speaker-Diarization/blob/main/nvidia_nemo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#First we need to mount google drive.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Installing Nemo toolkit and other requires tools
# !apt-get install sox libsndfile1 ffmpeg
## Install NeMo
BRANCH = 'main'
# !python -m pip install git+https://github.com/NVIDIA/NeMo.git@$BRANCH#egg=nemo_toolkit[asr]

# Install TorchAudio
# !pip install torchaudio>=0.10.0 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libsndfile1 is already the newest version (1.0.28-7ubuntu0.1).
# ffmpeg is already the newest version (7:4.2.7-0ubuntu0.1).
# The following additional packages will be installed:
#   libopencore-amrnb0 libopencore-amrwb0 libsox-fmt-alsa libsox-fmt-base
#   libsox3
# Suggested packages:
#   libsox-fmt-all
# The following NEW packages will be installed:
#   libopencore-amrnb0 libopencore-amrwb0 libsox-fmt-alsa libsox-fmt-base
#   libsox3 sox
# 0 upgraded, 6 newly installed, 0 to remove and 24 not upgraded.
# Need to get 513 kB of archives.
# After this operation, 1,564 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 libopencore-amrnb0 amd64 0.1.5-1 [94.8 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/universe amd64 libopencore-amrwb0 amd64 0.1.5-1 [49.1 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libsox3 amd64 14.4.2+git20190427-2+deb11u2build0.20.04.1 [225 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libsox-fmt-alsa amd64 14.4.2+git20190427-2+deb11u2build0.20.04.1 [10.5 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 libsox-fmt-base amd64 14.4.2+git20190427-2+deb11u2build0.20.04.1 [31.4 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 sox amd64 14.4.2+git20190427-2+deb11u2build0.20.04.1 [102 kB]
# Fetched 513 kB in 1s (349 kB/s)
# Selecting previously unselected package libopencore-amrnb0:amd64.
# (Reading database ... 122520 files and directories currently installed.)
# Preparing to unpack .../0-libopencore-amrnb0_0.1.5-1_amd64.deb ...
# Unpacking libopencore-amrnb0:amd64 (0.1.5-1) ...
# Selecting previously unselected package libopencore-amrwb0:amd64.
# Preparing to unpack .../1-libopencore-amrwb0_0.1.5-1_amd64.deb ...
# Unpacking libopencore-amrwb0:amd64 (0.1.5-1) ...
# Selecting previously unselected package libsox3:amd64.
# Preparing to unpack .../2-libsox3_14.4.2+git20190427-2+deb11u2build0.20.04.1_amd64.deb ...
# Unpacking libsox3:amd64 (14.4.2+git20190427-2+deb11u2build0.20.04.1) ...
# Selecting previously unselected package libsox-fmt-alsa:amd64.
# Preparing to unpack .../3-libsox-fmt-alsa_14.4.2+git20190427-2+deb11u2build0.20.04.1_amd64.deb ...
# Unpacking libsox-fmt-alsa:amd64 (14.4.2+git20190427-2+deb11u2build0.20.04.1) ...
# Selecting previously unselected package libsox-fmt-base:amd64.
# Preparing to unpack .../4-libsox-fmt-base_14.4.2+git20190427-2+deb11u2build0.20.04.1_amd64.deb ...
# Unpacking libsox-fmt-base:amd64 (14.4.2+git20190427-2+deb11u2build0.20.04.1) ...
# Selecting previously unselected package sox.
# Preparing to unpack .../5-sox_14.4.2+git20190427-2+deb11u2build0.20.04.1_amd64.deb ...
# Unpacking sox (14.4.2+git20190427-2+deb11u2build0.20.04.1) ...
# Setting up libsox3:amd64 (14.4.2+git20190427-2+deb11u2build0.20.04.1) ...
# Setting up libopencore-amrwb0:amd64 (0.1.5-1) ...
# Setting up libsox-fmt-alsa:amd64 (14.4.2+git20190427-2+deb11u2build0.20.04.1) ...
# Setting up libopencore-amrnb0:amd64 (0.1.5-1) ...
# Setting up libsox-fmt-base:amd64 (14.4.2+git20190427-2+deb11u2build0.20.04.1) ...
# Setting up sox (14.4.2+git20190427-2+deb11u2build0.20.04.1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for mime-support (3.64ubuntu1) ...
# DEPRECATION: git+https://github.com/NVIDIA/NeMo.git@main#egg=nemo_toolkit[asr] contains an egg fragment with a non-PEP 508 name pip 25.0 will enforce this behaviour change. A possible replacement is to use the req @ url syntax, and remove the egg fragment. Discussion can be found at https://github.com/pypa/pip/issues/11617
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting nemo_toolkit[asr]
#   Cloning https://github.com/NVIDIA/NeMo.git (to revision main) to /tmp/pip-install-08jyovn_/nemo-toolkit_617c3d016c0d4f6d84499e432595d2bd
#   Running command git clone --filter=blob:none --quiet https://github.com/NVIDIA/NeMo.git /tmp/pip-install-08jyovn_/nemo-toolkit_617c3d016c0d4f6d84499e432595d2bd
#   Resolved https://github.com/NVIDIA/NeMo.git to commit 29c8ac39c9047b965b248569328d6217bf5f5e4d
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting huggingface-hub (from nemo_toolkit[asr])
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]) (0.56.4)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]) (1.22.4)
# Collecting onnx>=1.7.0 (from nemo_toolkit[asr])
#   Downloading onnx-1.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 97.7 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]) (2.8.2)
# Collecting ruamel.yaml (from nemo_toolkit[asr])
#   Downloading ruamel.yaml-0.17.26-py3-none-any.whl (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.1/109.1 kB 15.5 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]) (1.2.2)
# Collecting setuptools==65.5.1 (from nemo_toolkit[asr])
#   Downloading setuptools-65.5.1-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 72.1 MB/s eta 0:00:00
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]) (2.12.2)
# Requirement already satisfied: text-unidecode in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]) (1.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]) (2.0.0+cu118)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]) (4.65.0)
# Collecting wget (from nemo_toolkit[asr])
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]) (1.14.1)
# Collecting braceexpand (from nemo_toolkit[asr])
#   Downloading braceexpand-0.1.7-py2.py3-none-any.whl (5.9 kB)
# Requirement already satisfied: editdistance in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]) (0.6.2)
# Collecting g2p-en (from nemo_toolkit[asr])
#   Downloading g2p_en-2.1.0-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 95.4 MB/s eta 0:00:00
# Requirement already satisfied: inflect in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]) (6.0.4)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]) (7.7.1)
# Collecting jiwer (from nemo_toolkit[asr])
#   Downloading jiwer-3.0.1-py3-none-any.whl (21 kB)
# Collecting kaldi-python-io (from nemo_toolkit[asr])
#   Downloading kaldi-python-io-1.2.2.tar.gz (8.8 kB)
#   Preparing metadata (setup.py) ... done
# Collecting kaldiio (from nemo_toolkit[asr])
#   Downloading kaldiio-2.18.0-py3-none-any.whl (28 kB)
# Requirement already satisfied: librosa>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]) (0.10.0.post2)
# Collecting marshmallow (from nemo_toolkit[asr])
#   Downloading marshmallow-3.19.0-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]) (3.7.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]) (23.1)
# Collecting pyannote.core (from nemo_toolkit[asr])
#   Downloading pyannote.core-5.0.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.5/58.5 kB 3.8 MB/s eta 0:00:00
# Collecting pyannote.metrics (from nemo_toolkit[asr])
#   Downloading pyannote.metrics-3.2.1-py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.4/51.4 kB 6.0 MB/s eta 0:00:00
# Collecting pydub (from nemo_toolkit[asr])
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]) (1.10.1)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]) (0.12.1)
# Collecting sox (from nemo_toolkit[asr])
#   Downloading sox-1.4.1-py2.py3-none-any.whl (39 kB)
# Collecting texterrors (from nemo_toolkit[asr])
#   Downloading texterrors-0.4.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 70.5 MB/s eta 0:00:00
# Collecting hydra-core<1.3,>=1.2.0 (from nemo_toolkit[asr])
#   Downloading hydra_core-1.2.0-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.1/151.1 kB 20.1 MB/s eta 0:00:00
# Collecting omegaconf<2.3,>=2.2 (from nemo_toolkit[asr])
#   Downloading omegaconf-2.2.3-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.3/79.3 kB 8.9 MB/s eta 0:00:00
# Collecting pytorch-lightning<=1.9.4,>=1.9.0 (from nemo_toolkit[asr])
#   Downloading pytorch_lightning-1.9.4-py3-none-any.whl (827 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 827.8/827.8 kB 56.7 MB/s eta 0:00:00
# Collecting pyyaml<6 (from nemo_toolkit[asr])
#   Downloading PyYAML-5.4.1.tar.gz (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.1/175.1 kB 20.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting torchmetrics>=0.11.0 (from nemo_toolkit[asr])
#   Downloading torchmetrics-0.11.4-py3-none-any.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.2/519.2 kB 46.3 MB/s eta 0:00:00
# Collecting transformers>=4.0.1 (from nemo_toolkit[asr])
#   Downloading transformers-4.29.1-py3-none-any.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 117.2 MB/s eta 0:00:00
# Collecting wandb (from nemo_toolkit[asr])
#   Downloading wandb-0.15.2-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 98.3 MB/s eta 0:00:00
# Collecting webdataset<=0.1.62,>=0.1.48 (from nemo_toolkit[asr])
#   Downloading webdataset-0.1.62-py3-none-any.whl (32 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from nemo_toolkit[asr]) (1.5.3)
# Collecting sacremoses>=0.0.43 (from nemo_toolkit[asr])
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 kB 64.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting sentencepiece<1.0.0 (from nemo_toolkit[asr])
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 74.0 MB/s eta 0:00:00
# Collecting youtokentome>=1.0.5 (from nemo_toolkit[asr])
#   Downloading youtokentome-1.0.6.tar.gz (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 11.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core<1.3,>=1.2.0->nemo_toolkit[asr])
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 15.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.9.0->nemo_toolkit[asr]) (3.0.0)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.9.0->nemo_toolkit[asr]) (1.2.0)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.9.0->nemo_toolkit[asr]) (4.4.2)
# Requirement already satisfied: pooch<1.7,>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.9.0->nemo_toolkit[asr]) (1.6.0)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.9.0->nemo_toolkit[asr]) (0.3.5)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.9.0->nemo_toolkit[asr]) (4.5.0)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.9.0->nemo_toolkit[asr]) (0.2)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.9.0->nemo_toolkit[asr]) (1.0.5)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->nemo_toolkit[asr]) (0.39.1)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.10/dist-packages (from onnx>=1.7.0->nemo_toolkit[asr]) (3.20.3)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning<=1.9.4,>=1.9.0->nemo_toolkit[asr]) (2023.4.0)
# Collecting lightning-utilities>=0.6.0.post0 (from pytorch-lightning<=1.9.4,>=1.9.0->nemo_toolkit[asr])
#   Downloading lightning_utilities-0.8.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacremoses>=0.0.43->nemo_toolkit[asr]) (2022.10.31)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from sacremoses>=0.0.43->nemo_toolkit[asr]) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from sacremoses>=0.0.43->nemo_toolkit[asr]) (8.1.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->nemo_toolkit[asr]) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile->nemo_toolkit[asr]) (1.15.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->nemo_toolkit[asr]) (3.12.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->nemo_toolkit[asr]) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->nemo_toolkit[asr]) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->nemo_toolkit[asr]) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->nemo_toolkit[asr]) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->nemo_toolkit[asr]) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->nemo_toolkit[asr]) (16.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers>=4.0.1->nemo_toolkit[asr]) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers>=4.0.1->nemo_toolkit[asr])
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 116.3 MB/s eta 0:00:00
# Requirement already satisfied: nltk>=3.2.4 in /usr/local/lib/python3.10/dist-packages (from g2p-en->nemo_toolkit[asr]) (3.8.1)
# Collecting distance>=0.1.3 (from g2p-en->nemo_toolkit[asr])
#   Downloading Distance-0.1.3.tar.gz (180 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.3/180.3 kB 22.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pydantic>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from inflect->nemo_toolkit[asr]) (1.10.7)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->nemo_toolkit[asr]) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->nemo_toolkit[asr]) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->nemo_toolkit[asr]) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->nemo_toolkit[asr]) (3.6.4)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->nemo_toolkit[asr]) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->nemo_toolkit[asr]) (3.0.7)
# Collecting rapidfuzz==2.13.7 (from jiwer->nemo_toolkit[asr])
#   Downloading rapidfuzz-2.13.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 68.0 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->nemo_toolkit[asr]) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->nemo_toolkit[asr]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->nemo_toolkit[asr]) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->nemo_toolkit[asr]) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->nemo_toolkit[asr]) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->nemo_toolkit[asr]) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->nemo_toolkit[asr]) (2022.7.1)
# Requirement already satisfied: sortedcontainers>=2.0.4 in /usr/local/lib/python3.10/dist-packages (from pyannote.core->nemo_toolkit[asr]) (2.4.0)
# Collecting pyannote.database>=4.0.1 (from pyannote.metrics->nemo_toolkit[asr])
#   Downloading pyannote.database-5.0.1-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 5.6 MB/s eta 0:00:00
# Collecting docopt>=0.6.2 (from pyannote.metrics->nemo_toolkit[asr])
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from pyannote.metrics->nemo_toolkit[asr]) (0.8.10)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml->nemo_toolkit[asr])
#   Downloading ruamel.yaml.clib-0.2.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (485 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.6/485.6 kB 42.2 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard->nemo_toolkit[asr]) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->nemo_toolkit[asr]) (1.54.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard->nemo_toolkit[asr]) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard->nemo_toolkit[asr]) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->nemo_toolkit[asr]) (3.4.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->nemo_toolkit[asr]) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->nemo_toolkit[asr]) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard->nemo_toolkit[asr]) (2.3.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard->nemo_toolkit[asr]) (0.40.0)
# Collecting pybind11 (from texterrors->nemo_toolkit[asr])
#   Downloading pybind11-2.10.4-py3-none-any.whl (222 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.3/222.3 kB 25.2 MB/s eta 0:00:00
# Collecting plac (from texterrors->nemo_toolkit[asr])
#   Downloading plac-1.3.5-py2.py3-none-any.whl (22 kB)
# Collecting loguru (from texterrors->nemo_toolkit[asr])
#   Downloading loguru-0.7.0-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from texterrors->nemo_toolkit[asr]) (2.3.0)
# Collecting Levenshtein (from texterrors->nemo_toolkit[asr])
#   Downloading Levenshtein-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (174 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.1/174.1 kB 15.8 MB/s eta 0:00:00
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb->nemo_toolkit[asr])
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 20.8 MB/s eta 0:00:00
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb->nemo_toolkit[asr]) (5.9.5)
# Collecting sentry-sdk>=1.0.0 (from wandb->nemo_toolkit[asr])
#   Downloading sentry_sdk-1.23.0-py2.py3-none-any.whl (205 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 205.1/205.1 kB 22.1 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0 (from wandb->nemo_toolkit[asr])
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting pathtools (from wandb->nemo_toolkit[asr])
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting setproctitle (from wandb->nemo_toolkit[asr])
#   Downloading setproctitle-1.3.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb->nemo_toolkit[asr]) (1.4.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile->nemo_toolkit[asr]) (2.21)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]>2021.06.0->pytorch-lightning<=1.9.4,>=1.9.0->nemo_toolkit[asr])
#   Downloading aiohttp-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 60.6 MB/s eta 0:00:00
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb->nemo_toolkit[asr])
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->nemo_toolkit[asr]) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->nemo_toolkit[asr]) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->nemo_toolkit[asr]) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->nemo_toolkit[asr]) (1.3.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[asr]) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[asr]) (6.3.1)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets->nemo_toolkit[asr])
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 87.3 MB/s eta 0:00:00
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[asr]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[asr]) (3.0.38)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[asr]) (2.14.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[asr]) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[asr]) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[asr]) (4.8.0)
# Requirement already satisfied: typer[all]>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[asr]) (0.7.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.0.1->nemo_toolkit[asr]) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.0.1->nemo_toolkit[asr]) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.0.1->nemo_toolkit[asr]) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.0.1->nemo_toolkit[asr]) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->nemo_toolkit[asr]) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard->nemo_toolkit[asr]) (2.1.2)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (6.4.8)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<=1.9.4,>=1.9.0->nemo_toolkit[asr]) (23.1.0)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<=1.9.4,>=1.9.0->nemo_toolkit[asr])
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 14.5 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<=1.9.4,>=1.9.0->nemo_toolkit[asr])
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<=1.9.4,>=1.9.0->nemo_toolkit[asr])
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 31.0 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<=1.9.4,>=1.9.0->nemo_toolkit[asr])
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 17.7 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<=1.9.4,>=1.9.0->nemo_toolkit[asr])
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb->nemo_toolkit[asr])
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->nemo_toolkit[asr]) (0.8.3)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (21.3.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (5.3.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (5.8.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (1.5.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (0.17.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (0.16.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->nemo_toolkit[asr]) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->nemo_toolkit[asr]) (0.2.6)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->nemo_toolkit[asr]) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->nemo_toolkit[asr]) (3.2.2)
# Collecting colorama<0.5.0,>=0.4.3 (from typer[all]>=0.2.1->pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[asr])
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting shellingham<2.0.0,>=1.3.0 (from typer[all]>=0.2.1->pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[asr])
#   Downloading shellingham-1.5.0.post1-py2.py3-none-any.whl (9.4 kB)
# Collecting rich<13.0.0,>=10.11.0 (from typer[all]>=0.2.1->pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[asr])
#   Downloading rich-12.6.0-py3-none-any.whl (237 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 237.5/237.5 kB 28.5 MB/s eta 0:00:00
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (3.3.0)
# Collecting commonmark<0.10.0,>=0.9.0 (from rich<13.0.0,>=10.11.0->typer[all]>=0.2.1->pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[asr])
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.1/51.1 kB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (21.2.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (4.11.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (6.0.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (0.7.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (1.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (2.16.3)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (4.3.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (0.19.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (2.4.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[asr]) (0.5.1)
# Building wheels for collected packages: antlr4-python3-runtime, pyyaml, sacremoses, youtokentome, kaldi-python-io, nemo_toolkit, wget, distance, docopt, pathtools
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=20a9d857b94580accd74ce4467c1b5dd47f1ad09f23c5d31c9f14d7242fb2577
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
#   Building wheel for pyyaml (pyproject.toml) ... done
#   Created wheel for pyyaml: filename=PyYAML-5.4.1-cp310-cp310-linux_x86_64.whl size=45658 sha256=3fb8e4754648ea294478def5ac611cd5a5bab05f6ea2399f3fe4b250cf03d32d
#   Stored in directory: /root/.cache/pip/wheels/c7/0d/22/696ee92245ad710f506eee79bb05c740d8abccd3ecdb778683
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895241 sha256=9bb607422ce5af64d1478829092db9d7d4382262091fda9d18aff30218570462
#   Stored in directory: /root/.cache/pip/wheels/00/24/97/a2ea5324f36bc626e1ea0267f33db6aa80d157ee977e9e42fb
#   Building wheel for youtokentome (setup.py) ... done
#   Created wheel for youtokentome: filename=youtokentome-1.0.6-cp310-cp310-linux_x86_64.whl size=1927606 sha256=eb8bc79f5a26d6366a19d6ce79bc72ffda64029c296d6debb9fde522c7cdc8c4
#   Stored in directory: /root/.cache/pip/wheels/df/85/f8/301d2ba45f43f30bed2fe413efa760bc726b8b660ed9c2900c
#   Building wheel for kaldi-python-io (setup.py) ... done
#   Created wheel for kaldi-python-io: filename=kaldi_python_io-1.2.2-py3-none-any.whl size=8951 sha256=605161779fb440879d97efbe738fef6d02fbe6be99dfcfceba00c22fffe2dec3
#   Stored in directory: /root/.cache/pip/wheels/b7/23/5f/49d3a826be576faf61d84e8028e1914bb36a5586ee2613b087
#   Building wheel for nemo_toolkit (pyproject.toml) ... done
#   Created wheel for nemo_toolkit: filename=nemo_toolkit-1.19.0rc0-py3-none-any.whl size=2367620 sha256=a60b9adbcf273038b3fb066c18eadeb672995ecee922868fd12848615a45082c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-iqh86bk3/wheels/6c/d2/4f/1572b895b6a4dbd9fdf534c882d9bc6e94e700a6db5bb20423
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9657 sha256=2b48039133060b96cfad9b0bdd9af1c7f37a192de880e8364d3c11f26b77baff
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
#   Building wheel for distance (setup.py) ... done
#   Created wheel for distance: filename=Distance-0.1.3-py3-none-any.whl size=16258 sha256=952edc3ad2a138d61a1b7eaf46f656de16a0c78cb06913161ba2736482b7b55d
#   Stored in directory: /root/.cache/pip/wheels/e8/bb/de/f71bf63559ea9a921059a5405806f7ff6ed612a9231c4a9309
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13707 sha256=9a3b1ab4678afe1c762f0cf116611c70afd139f8dc2a9f8e35f20fc99cf5638a
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8791 sha256=7471244b2000d7ca5e5abc5a19b53d78080b233747d128354cbd8277e1c7f91f
#   Stored in directory: /root/.cache/pip/wheels/e7/f3/22/152153d6eb222ee7a56ff8617d80ee5207207a8c00a7aab794
# Successfully built antlr4-python3-runtime pyyaml sacremoses youtokentome kaldi-python-io nemo_toolkit wget distance docopt pathtools
# Installing collected packages: wget, tokenizers, sentencepiece, pydub, plac, pathtools, docopt, distance, commonmark, braceexpand, antlr4-python3-runtime, youtokentome, webdataset, sox, smmap, shellingham, setuptools, setproctitle, sentry-sdk, sacremoses, ruamel.yaml.clib, rich, rapidfuzz, pyyaml, pybind11, onnx, multidict, marshmallow, loguru, lightning-utilities, kaldiio, kaldi-python-io, jedi, frozenlist, docker-pycreds, colorama, async-timeout, yarl, ruamel.yaml, pyannote.core, omegaconf, Levenshtein, jiwer, huggingface-hub, gitdb, aiosignal, transformers, texterrors, pyannote.database, hydra-core, GitPython, g2p-en, aiohttp, wandb, pyannote.metrics, torchmetrics, pytorch-lightning, nemo_toolkit
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 67.7.2
#     Uninstalling setuptools-67.7.2:
#       Successfully uninstalled setuptools-67.7.2
#   Attempting uninstall: rich
#     Found existing installation: rich 13.3.4
#     Uninstalling rich-13.3.4:
#       Successfully uninstalled rich-13.3.4
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cvxpy 1.3.1 requires setuptools>65.5.1, but you have setuptools 65.5.1 which is incompatible.
# Successfully installed GitPython-3.1.31 Levenshtein-0.21.0 aiohttp-3.8.4 aiosignal-1.3.1 antlr4-python3-runtime-4.9.3 async-timeout-4.0.2 braceexpand-0.1.7 colorama-0.4.6 commonmark-0.9.1 distance-0.1.3 docker-pycreds-0.4.0 docopt-0.6.2 frozenlist-1.3.3 g2p-en-2.1.0 gitdb-4.0.10 huggingface-hub-0.14.1 hydra-core-1.2.0 jedi-0.18.2 jiwer-3.0.1 kaldi-python-io-1.2.2 kaldiio-2.18.0 lightning-utilities-0.8.0 loguru-0.7.0 marshmallow-3.19.0 multidict-6.0.4 nemo_toolkit-1.19.0rc0 omegaconf-2.2.3 onnx-1.14.0 pathtools-0.1.2 plac-1.3.5 pyannote.core-5.0.0 pyannote.database-5.0.1 pyannote.metrics-3.2.1 pybind11-2.10.4 pydub-0.25.1 pytorch-lightning-1.9.4 pyyaml-5.4.1 rapidfuzz-2.13.7 rich-12.6.0 ruamel.yaml-0.17.26 ruamel.yaml.clib-0.2.7 sacremoses-0.0.53 sentencepiece-0.1.99 sentry-sdk-1.23.0 setproctitle-1.3.2 setuptools-65.5.1 shellingham-1.5.0.post1 smmap-5.0.0 sox-1.4.1 texterrors-0.4.4 tokenizers-0.13.3 torchmetrics-0.11.4 transformers-4.29.1 wandb-0.15.2 webdataset-0.1.62 wget-3.2 yarl-1.9.2 youtokentome-1.0.6

# %%
# Importing necessary libraries
import glob
import os
import wave
import contextlib
import subprocess
import numpy as np
from numpy.linalg import norm
from nemo.collections.asr.parts.utils.speaker_utils import embedding_normalize
from tqdm import  tqdm
try:
    from torch.cuda.amp import autocast
except ImportError:
    from contextlib import contextmanager

    @contextmanager
    def autocast(enabled=None):
        yield
import json
import pickle as pkl
import torch
import nemo
import nemo.collections.asr as nemo_asr
from omegaconf import OmegaConf
import time
# Out:
# [NeMo W 2023-05-16 18:27:53 optimizers:54] Apex was not found. Using the lamb or fused_adam optimizer will error out.
# [NeMo W 2023-05-16 18:27:56 experimental:27] Module <class 'nemo.collections.asr.modules.audio_modules.SpectrogramToMultichannelFeatures'> is experimental, not ready for production and is not fully supported. Use at your own risk.

# %%
#This function creates manifest which contains wave file path, duration and, speaker label.
#Speaker label is kept as dummy just to maintain the manifest format and will be not used for identification. 
#The generated manifest is used further to obtain the speaker embeddings.
def create_manifest_identification(wave_path,output_manifest_path):
  output = open(output_manifest_path,"w")
      # print(line1)
  main_dict = dict()
  with contextlib.closing(wave.open(wave_path,'r')) as f:
    frames = f.getnframes()
    rate = f.getframerate()
    dur = frames / float(rate)
  main_dict["audio_filepath"] = wave_path
  main_dict["duration"] = dur
  main_dict["label"] = "dummy_id"
  print(main_dict)
  output.write(json.dumps(main_dict))
  output.write('\n')
  output.close()

# %%
from torch.nn.modules import linear
# This function takes speaker model, manifest file path (generated by create_manifest_identification()/create_manifest_enroll_verfication() function)
# and embedding directory path (where embedding wil be saved) as must required arguments. 
#batch size and device can be passed according to the preference. It returns speaker embedding path (.pkl file) 
def obtain_embeddings(speaker_model, manifest_file,  embedding_dir, batch_size=1, device='cpu'):
      test_config = OmegaConf.create(
          dict(
              manifest_filepath=manifest_file,
              sample_rate=16000,
              labels=None,
              batch_size=batch_size,
              shuffle=False,
              time_length=20,
          )
      )

      speaker_model.setup_test_data(test_config)
      speaker_model = speaker_model.to(device)
      speaker_model.eval()

      all_embs=[]
      out_embeddings = {}
            
      for test_bat in tqdm(speaker_model.test_dataloader()):
          test_bat = [x.to(device) for x in test_bat]
          aud_signal, aud_signal_len, labels, slices = test_bat
          with autocast():
              _, embs = speaker_model.forward(input_signal=aud_signal, input_signal_length=aud_signal_len)
              emb_shape = embs.shape[-1]
              embs = embs.view(-1, emb_shape)
              all_embs.extend(embs.cpu().detach().numpy())
          del test_bat

      all_embs = np.asarray(all_embs)
      if len(all_embs)>1:
        all_embs = embedding_normalize(all_embs)
      with open(manifest_file, 'r') as manifest:
          for i, line in enumerate(manifest.readlines()):
              line = line.strip()
              dic = json.loads(line)
              uniq_name = dic['label']
              if uniq_name in out_embeddings.keys():

                pre_emb = out_embeddings[uniq_name]
                avg_emb = (pre_emb+all_embs[i])/2  #if enrollment already present averaging out it with new embeddings
                out_embeddings[uniq_name]=avg_emb

              else:
                out_embeddings[uniq_name] = all_embs[i] #adding new enrollment if not already present
              

      embedding_dir = os.path.join(embedding_dir, 'embeddings')
      if not os.path.exists(embedding_dir):
          os.makedirs(embedding_dir, exist_ok=True)
      prefix = manifest_file.split('/')[-1].rsplit('.', 1)[-2]
      name = os.path.join(embedding_dir, prefix)
      embeddings_file = name + '_embeddings.pkl'
      pkl.dump(out_embeddings, open(embeddings_file, 'wb'))
      return embeddings_file

# %%
#This fuction returns consine similarity score for two embedding passed.
def cosin_sim(A,B):
  cosine = np.dot(A,B)/(norm(A)*norm(B))
  return cosine

# %%
#This function is the overall wrapper for speaker identification.
#It take 3 arguments i.e. audio path, speaker_model (Inisialized in previous step) and, already enrolled embedding path.
#it creates a tmp dir as working directy to save manifest and speaker embeddings. 
def identification(audio_path,speaker_model,enrolled_emb_path,threshould=0.4):
  start_time = time.time()
  output_dict = dict()
  output_dir = "/content/drive/MyDrive/nvidia-nemo-voxceleb/tmp/" #Please pass the apropriate path for tmp folder
  if not os.path.exists(output_dir):
    os.mkdir(output_dir)
  output_manifest_path = output_dir + "identify_manifest.json"
  embedding_dir = output_dir
  create_manifest_identification(audio_path,output_manifest_path)
  spk_emb_path = obtain_embeddings(speaker_model, output_manifest_path,embedding_dir,batch_size=1, device='cpu')
  identify_emb_pkl=pkl.load(open(spk_emb_path, "rb"))
  enrolled_emb_pkl=pkl.load(open(enrolled_emb_path, "rb"))
  higest_score = 0
  speaker_name = None
  for key in identify_emb_pkl:
    ver_emb=identify_emb_pkl[key]
    verify_key=key
    for key in enrolled_emb_pkl:
      emb = enrolled_emb_pkl[key]
      speaker = key
      score = cosin_sim(emb,ver_emb)



      if score > higest_score:
        if score > threshould:
          # print("speaker:",speaker)
          speaker_name = speaker
          higest_score = score
          actual_speaker = verify_key

  if higest_score==0:
    output_dict["status"] = "We could not verify"
    # print("We could not verify")
  else:
    # print("Identification done")
    output_dict["status"] = "Identification done"
    # print("Speaker name:", speaker_name , " Score: ",higest_score)
    output_dict["Speaker_name"] = speaker_name
    output_dict["score"] = higest_score

  end_time = time.time()
  time_elapsed = end_time - start_time
  # print ("Time taken: ",time_elapsed)
  output_dict["Time_taken"] = time_elapsed
  print("output: ",output_dict)

# %%
#Setting up the NeMo pretrained speaker model to be used to generate the speaker embeddings
#Note: The enrollment is done using Nemo pretained titanet_large speaker model.
spk_model = nemo_asr.models.EncDecSpeakerLabelModel.from_pretrained(model_name='titanet_large')
# Out:
# [NeMo I 2023-05-16 18:51:58 cloud:58] Found existing object /root/.cache/torch/NeMo/NeMo_1.19.0rc0/titanet-l/11ba0924fdf87c049e339adbf6899d48/titanet-l.nemo.
# [NeMo I 2023-05-16 18:51:58 cloud:64] Re-using file from: /root/.cache/torch/NeMo/NeMo_1.19.0rc0/titanet-l/11ba0924fdf87c049e339adbf6899d48/titanet-l.nemo
# [NeMo I 2023-05-16 18:51:58 common:913] Instantiating model from pre-trained checkpoint
# [NeMo W 2023-05-16 18:51:58 modelPT:161] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     manifest_filepath: /manifests/combined_fisher_swbd_voxceleb12_librispeech/train.json
#     sample_rate: 16000
#     labels: null
#     batch_size: 64
#     shuffle: true
#     is_tarred: false
#     tarred_audio_filepaths: null
#     tarred_shard_strategy: scatter
#     augmentor:
#       noise:
#         manifest_path: /manifests/noise/rir_noise_manifest.json
#         prob: 0.5
#         min_snr_db: 0
#         max_snr_db: 15
#       speed:
#         prob: 0.5
#         sr: 16000
#         resample_type: kaiser_fast
#         min_speed_rate: 0.95
#         max_speed_rate: 1.05
#     num_workers: 15
#     pin_memory: true
#
# [NeMo W 2023-05-16 18:51:58 modelPT:168] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     manifest_filepath: /manifests/combined_fisher_swbd_voxceleb12_librispeech/dev.json
#     sample_rate: 16000
#     labels: null
#     batch_size: 128
#     shuffle: false
#     num_workers: 15
#     pin_memory: true
# [NeMo I 2023-05-16 18:51:58 features:291] PADDING: 16
# [NeMo I 2023-05-16 18:51:58 save_restore_connector:249] Model EncDecSpeakerLabelModel was successfully restored from /root/.cache/torch/NeMo/NeMo_1.19.0rc0/titanet-l/11ba0924fdf87c049e339adbf6899d48/titanet-l.nemo.

# %%
import time
#audio path for identification
audio_path = "/content/drive/MyDrive/nvidia-nemo-voxceleb/id10289.wav" #Please pass the apropriate path
# Enrolled embedding path
enrolled_emb_path = "/content/drive/MyDrive/nvidia-nemo-voxceleb/data/embeddings/train_6_speaker_embeddings.pkl" #Please pass the apropriate path
threshold = 0.4 # Set threshould value
# call identification function and passing the arugments
identification(audio_path,spk_model,enrolled_emb_path,threshold)
# Out:
# {'audio_filepath': '/content/drive/MyDrive/nvidia-nemo-voxceleb/id10289.wav', 'duration': 7.2800625, 'label': 'dummy_id'}
# [NeMo I 2023-05-16 18:52:00 collections:298] Filtered duration for loading collection is  0.00 hours.
# [NeMo I 2023-05-16 18:52:00 collections:299] Dataset loaded with 1 items, total duration of  0.00 hours.
# [NeMo I 2023-05-16 18:52:00 collections:301] # 1 files loaded accounting to # 1 labels
# 100%|██████████| 1/1 [00:00<00:00,  1.85it/s]
# /content/drive/MyDrive/nvidia-nemo-voxceleb/tmp/identify_manifest.json
# identify_manifest
# output:  {'status': 'Identification done', 'Speaker_name': 'id10289', 'score': 0.85525507, 'Time_taken': 0.600888729095459}
